# %%
import pandas as pd

# %%
df = pd.read_csv("realtor-data.csv")

# %%
df
# Out:
#           status  bed  bath  acre_lot           city        state  zip_code  \
# 0       for_sale  3.0   2.0      0.12       Adjuntas  Puerto Rico     601.0
# 1       for_sale  4.0   2.0      0.08       Adjuntas  Puerto Rico     601.0
# 2       for_sale  2.0   1.0      0.15     Juana Diaz  Puerto Rico     795.0
# 3       for_sale  4.0   2.0      0.10          Ponce  Puerto Rico     731.0
# 4       for_sale  6.0   2.0      0.05       Mayaguez  Puerto Rico     680.0
# ...          ...  ...   ...       ...            ...          ...       ...
# 407885  for_sale  4.0   1.0      0.26        Windham  Connecticut    6226.0
# 407886  for_sale  2.0   1.0      0.23  East Hartford  Connecticut    6118.0
# 407887  for_sale  4.0   1.0      0.33   Wethersfield  Connecticut    6109.0
# 407888  for_sale  4.0   3.0      2.34       Coventry  Connecticut    6238.0
# 407889  for_sale  2.0   1.0      0.91   East Windsor  Connecticut    6016.0
#
#         house_size prev_sold_date     price
# ...

# %%
df.columns
# Out:
# Index(['status', 'bed', 'bath', 'acre_lot', 'city', 'state', 'zip_code',
#        'house_size', 'prev_sold_date', 'price'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 407890 entries, 0 to 407889
# Data columns (total 10 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   status          407890 non-null  object
#  1   bed             320108 non-null  float64
#  2   bath            321618 non-null  float64
#  3   acre_lot        331873 non-null  float64
#  4   city            407838 non-null  object
#  5   state           407890 non-null  object
#  6   zip_code        407693 non-null  float64
#  7   house_size      324365 non-null  float64
#  8   prev_sold_date  140950 non-null  object
#  9   price           407890 non-null  float64
# dtypes: float64(6), object(4)
# memory usage: 31.1+ MB

# %%
df.shape
# Out:
# (407890, 10)

# %%
pd.set_option("display.max_columns", 10)

# %%
df
# Out:
#           status  bed  bath  acre_lot           city        state  zip_code  \
# 0       for_sale  3.0   2.0      0.12       Adjuntas  Puerto Rico     601.0
# 1       for_sale  4.0   2.0      0.08       Adjuntas  Puerto Rico     601.0
# 2       for_sale  2.0   1.0      0.15     Juana Diaz  Puerto Rico     795.0
# 3       for_sale  4.0   2.0      0.10          Ponce  Puerto Rico     731.0
# 4       for_sale  6.0   2.0      0.05       Mayaguez  Puerto Rico     680.0
# ...          ...  ...   ...       ...            ...          ...       ...
# 407885  for_sale  4.0   1.0      0.26        Windham  Connecticut    6226.0
# 407886  for_sale  2.0   1.0      0.23  East Hartford  Connecticut    6118.0
# 407887  for_sale  4.0   1.0      0.33   Wethersfield  Connecticut    6109.0
# 407888  for_sale  4.0   3.0      2.34       Coventry  Connecticut    6238.0
# 407889  for_sale  2.0   1.0      0.91   East Windsor  Connecticut    6016.0
#
#         house_size prev_sold_date     price
# ...

# %%
pd.set_option("display.max_rows",20)

# %%
df.head(20)
# Out:
#       status  bed  bath  acre_lot           city        state  zip_code  \
# 0   for_sale  3.0   2.0      0.12       Adjuntas  Puerto Rico     601.0
# 1   for_sale  4.0   2.0      0.08       Adjuntas  Puerto Rico     601.0
# 2   for_sale  2.0   1.0      0.15     Juana Diaz  Puerto Rico     795.0
# 3   for_sale  4.0   2.0      0.10          Ponce  Puerto Rico     731.0
# 4   for_sale  6.0   2.0      0.05       Mayaguez  Puerto Rico     680.0
# 5   for_sale  4.0   3.0      0.46  San Sebastian  Puerto Rico     612.0
# 6   for_sale  3.0   1.0      0.20         Ciales  Puerto Rico     639.0
# 7   for_sale  3.0   2.0      0.08          Ponce  Puerto Rico     731.0
# 8   for_sale  2.0   1.0      0.09          Ponce  Puerto Rico     730.0
# 9   for_sale  5.0   3.0      7.46     Las Marias  Puerto Rico     670.0
# 10  for_sale  3.0   2.0     13.39        Isabela  Puerto Rico     662.0
# 11  for_sale  3.0   2.0      0.08     Juana Diaz  Puerto Rico     795.0
# ...

# %%
# create a index column that starts with 1

df['index'] = df.index + 1

# %%
# set the index column as the index of this data set

df.set_index('index',inplace = True)

# %%
df
# Out:
#           status  bed  bath  acre_lot           city        state  zip_code  \
# index
# 1       for_sale  3.0   2.0      0.12       Adjuntas  Puerto Rico     601.0
# 2       for_sale  4.0   2.0      0.08       Adjuntas  Puerto Rico     601.0
# 3       for_sale  2.0   1.0      0.15     Juana Diaz  Puerto Rico     795.0
# 4       for_sale  4.0   2.0      0.10          Ponce  Puerto Rico     731.0
# 5       for_sale  6.0   2.0      0.05       Mayaguez  Puerto Rico     680.0
# ...          ...  ...   ...       ...            ...          ...       ...
# 407886  for_sale  4.0   1.0      0.26        Windham  Connecticut    6226.0
# 407887  for_sale  2.0   1.0      0.23  East Hartford  Connecticut    6118.0
# 407888  for_sale  4.0   1.0      0.33   Wethersfield  Connecticut    6109.0
# 407889  for_sale  4.0   3.0      2.34       Coventry  Connecticut    6238.0
# 407890  for_sale  2.0   1.0      0.91   East Windsor  Connecticut    6016.0
#
#         house_size prev_sold_date     price
# ...

# %%
df.head(10)
# Out:
#          status  bed  bath  acre_lot           city        state  zip_code  \
# index
# 1      for_sale  3.0   2.0      0.12       Adjuntas  Puerto Rico     601.0
# 2      for_sale  4.0   2.0      0.08       Adjuntas  Puerto Rico     601.0
# 3      for_sale  2.0   1.0      0.15     Juana Diaz  Puerto Rico     795.0
# 4      for_sale  4.0   2.0      0.10          Ponce  Puerto Rico     731.0
# 5      for_sale  6.0   2.0      0.05       Mayaguez  Puerto Rico     680.0
# 6      for_sale  4.0   3.0      0.46  San Sebastian  Puerto Rico     612.0
# 7      for_sale  3.0   1.0      0.20         Ciales  Puerto Rico     639.0
# 8      for_sale  3.0   2.0      0.08          Ponce  Puerto Rico     731.0
# 9      for_sale  2.0   1.0      0.09          Ponce  Puerto Rico     730.0
# 10     for_sale  5.0   3.0      7.46     Las Marias  Puerto Rico     670.0
#
#        house_size prev_sold_date     price
# index
# 1           920.0            NaN  105000.0
# ...

# %%
df['status'].value_counts()
# Out:
# for_sale          407130
# ready_to_build       760
# Name: status, dtype: int64

# %%
# we would want the data by state so please group by it by states

st = df.groupby(["state"])

# %%
st.get_group("New Jersey")
# Out:
#           status  bed  bath  acre_lot        city       state  zip_code  \
# index
# 30127   for_sale  3.0   3.0      0.07  Burlington  New Jersey    8016.0
# 45321   for_sale  3.0   3.0      0.07  Burlington  New Jersey    8016.0
# 385083  for_sale  3.0   3.0      0.07  Burlington  New Jersey    8016.0
# 388798  for_sale  3.0   3.0      0.07  Burlington  New Jersey    8016.0
# 389916  for_sale  3.0   3.0      0.07  Burlington  New Jersey    8016.0
# 391131  for_sale  3.0   3.0      0.07  Burlington  New Jersey    8016.0
# 391282  for_sale  3.0   3.0      0.07  Burlington  New Jersey    8016.0
# 391493  for_sale  3.0   3.0      0.07  Burlington  New Jersey    8016.0
# 394088  for_sale  3.0   3.0      0.07  Burlington  New Jersey    8016.0
# 395668  for_sale  3.0   3.0      0.07  Burlington  New Jersey    8016.0
# 397693  for_sale  3.0   3.0      0.07  Burlington  New Jersey    8016.0
# 400016  for_sale  3.0   3.0      0.07  Burlington  New Jersey    8016.0
# ...

# %%
#find out which state have highest homes for sale

st['status'].value_counts().head(50)
# Out:
# state           status
# Connecticut     for_sale           38180
# Georgia         for_sale              48
# Maine           for_sale           36650
# Massachusetts   for_sale          172719
#                 ready_to_build       760
# New Hampshire   for_sale           51394
# New Jersey      for_sale              13
# New York        for_sale            5829
# Puerto Rico     for_sale           24679
# Rhode Island    for_sale           28518
# South Carolina  for_sale              24
# Tennessee       for_sale              20
# Vermont         for_sale           46460
# Virgin Islands  for_sale            2573
# Virginia        for_sale              20
# Wyoming         for_sale               3
# Name: status, dtype: int64

# %%
pd.set_option("display.max_rows",50)

# %%
# look at the columns for Massachusetts
ma = st.get_group('Massachusetts')

# %%
ma
# Out:
#           status  bed  bath  acre_lot              city          state  \
# index
# 24232   for_sale  2.0   1.0      0.34            Agawam  Massachusetts
# 24233   for_sale  NaN   NaN      3.41            Agawam  Massachusetts
# 24234   for_sale  2.0   2.0       NaN            Agawam  Massachusetts
# 24235   for_sale  2.0   2.0       NaN            Agawam  Massachusetts
# 24236   for_sale  2.0   2.0       NaN            Agawam  Massachusetts
# ...          ...  ...   ...       ...               ...            ...
# 405920  for_sale  3.0   2.0      0.37  West Springfield  Massachusetts
# 405922  for_sale  2.0   1.0      0.12       Springfield  Massachusetts
# 405925  for_sale  3.0   2.0      0.38            Agawam  Massachusetts
# 405934  for_sale  6.0   3.0      0.13       Springfield  Massachusetts
# 406185  for_sale  4.0   1.0      0.17         Westfield  Massachusetts
#
#         zip_code  house_size prev_sold_date     price
# index
# ...

# %%
# describe the ma find out the min max value for ma

ma.describe()
# Out:
#                  bed           bath       acre_lot       zip_code  \
# count  147995.000000  148560.000000  127447.000000  173465.000000
# mean        3.523842       2.684922       3.989736    1896.809126
# std         2.892192       3.142699      71.819047     492.565351
# min         1.000000       1.000000       0.000000    1001.000000
# 25%         2.000000       2.000000       0.150000    1520.000000
# 50%         3.000000       2.000000       0.350000    2056.000000
# 75%         4.000000       3.000000       1.120000    2152.000000
# max        99.000000     198.000000    9035.000000    2893.000000
#
#           house_size         price
# count  149480.000000  1.734790e+05
# mean     2282.779348  9.815485e+05
# std      2588.731896  1.458548e+06
# min       104.000000  1.000000e+00
# 25%      1188.000000  3.500000e+05
# 50%      1784.000000  6.000000e+05
# 75%      2712.000000  9.750000e+05
# max     99999.000000  3.000000e+07

# %%
ma['price'].agg([max,min])
# Out:
# max    30000000.0
# min           1.0
# Name: price, dtype: float64

# %%
# only get the homes that are on sales

sales = ma['status'].str.contains('for_sale', na = False)

# %%
ma.loc[sales,'status':'price']
# Out:
#           status  bed  bath  acre_lot              city          state  \
# index
# 24232   for_sale  2.0   1.0      0.34            Agawam  Massachusetts
# 24233   for_sale  NaN   NaN      3.41            Agawam  Massachusetts
# 24234   for_sale  2.0   2.0       NaN            Agawam  Massachusetts
# 24235   for_sale  2.0   2.0       NaN            Agawam  Massachusetts
# 24236   for_sale  2.0   2.0       NaN            Agawam  Massachusetts
# ...          ...  ...   ...       ...               ...            ...
# 405920  for_sale  3.0   2.0      0.37  West Springfield  Massachusetts
# 405922  for_sale  2.0   1.0      0.12       Springfield  Massachusetts
# 405925  for_sale  3.0   2.0      0.38            Agawam  Massachusetts
# 405934  for_sale  6.0   3.0      0.13       Springfield  Massachusetts
# 406185  for_sale  4.0   1.0      0.17         Westfield  Massachusetts
#
#         zip_code  house_size prev_sold_date     price
# index
# ...

# %%
ma['bed'].value_counts()
# Out:
# 3.0     43925
# 2.0     37950
# 4.0     27745
# 1.0     11785
# 5.0     10578
# 6.0      6587
# 7.0      2288
# 8.0      2077
# 9.0      1811
# 12.0      911
# 10.0      647
# 11.0      503
# 15.0      200
# 14.0      123
# 18.0      116
# 13.0      108
# 16.0       86
# 19.0       85
# 20.0       84
# 24.0       72
# 17.0       67
# 22.0       46
# 28.0       35
# 42.0       28
# 60.0       27
# 99.0       23
# 86.0       21
# 32.0       21
# 31.0       17
# 33.0       10
# 21.0        8
# 49.0        8
# 27.0        3
# Name: bed, dtype: int64

# %%
# give me the rows where the bedroom is 49

bed = ma['bed'] == 49

# %%
ma.loc[bed,'status':'price']
# Out:
#           status   bed  bath  acre_lot        city          state  zip_code  \
# index
# 209059  for_sale  49.0  15.0      0.38  Fall River  Massachusetts    2721.0
# 210150  for_sale  49.0  15.0      0.38  Fall River  Massachusetts    2721.0
# 211426  for_sale  49.0  15.0      0.38  Fall River  Massachusetts    2721.0
# 215690  for_sale  49.0  15.0      0.38  Fall River  Massachusetts    2721.0
# 218835  for_sale  49.0  15.0      0.38  Fall River  Massachusetts    2721.0
# 219957  for_sale  49.0  15.0      0.38  Fall River  Massachusetts    2721.0
# 236294  for_sale  49.0  15.0      0.38  Fall River  Massachusetts    2721.0
# 237964  for_sale  49.0  15.0      0.38  Fall River  Massachusetts    2721.0
#
#         house_size prev_sold_date      price
# index
# 209059     15989.0            NaN  2000000.0
# 210150     15989.0            NaN  2000000.0
# 211426     15989.0            NaN  2000000.0
# 215690     15989.0            NaN  2000000.0
# ...

# %%
df.drop_duplicates()
# Out:
#           status  bed  bath  acre_lot        city        state  zip_code  \
# index
# 1       for_sale  3.0   2.0      0.12    Adjuntas  Puerto Rico     601.0
# 2       for_sale  4.0   2.0      0.08    Adjuntas  Puerto Rico     601.0
# 3       for_sale  2.0   1.0      0.15  Juana Diaz  Puerto Rico     795.0
# 4       for_sale  4.0   2.0      0.10       Ponce  Puerto Rico     731.0
# 5       for_sale  6.0   2.0      0.05    Mayaguez  Puerto Rico     680.0
# ...          ...  ...   ...       ...         ...          ...       ...
# 407866  for_sale  2.0   2.0       NaN      Hebron  Connecticut    6231.0
# 407871  for_sale  NaN   NaN      3.58     Andover  Connecticut    6232.0
# 407874  for_sale  NaN   NaN      0.92     Andover  Connecticut    6232.0
# 407879  for_sale  NaN   NaN    162.06     Andover  Connecticut    6232.0
# 407880  for_sale  3.0   2.0      4.87    Scotland  Connecticut    6280.0
#
#         house_size prev_sold_date     price
# index
# ...
